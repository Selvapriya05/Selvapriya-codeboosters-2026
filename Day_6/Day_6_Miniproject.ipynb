# %% [markdown]
# <a href="https://colab.research.google.com/github/Selvapriya05/Selvapriya-Codeboosters-2026/blob/main/Day_6/Day_6_Miniproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
extracted_records = [
    {
        "invoice_id": "INV-2024-0891",
        "vendor_name": "Techworld Solutions",
        "amount": 45000,
        "invoice_date": "2024-01-15",
        "category": "Electronics"
    },
    {
        "invoice_id": None,
        "vendor_name": "Priya Enterprises",
        "amount": 12500,
        "invoice_date": "2024-02-07",
        "category": "Services"
    },
    {
        "invoice_id": "INV-2024-103",
        "vendor_name": "Arjun Nair Consultancy",
        "amount": 8000,
        "invoice_date": "2024-03-15",
        "category": "Services"
    },
    {
        "invoice_id": None,
        "vendor_name": "Suresh Rao Hardware",
        "amount": 25000,
        "invoice_date": "2024-01-20",
        "category": "Accessories"
    },
    {
        "invoice_id": "INV-897",
        "vendor_name": "Ananya Tech Solutions",
        "amount": 95000,
        "invoice_date": "2024-02-28",
        "category": "Electronics"
    }
]

# %%
invoices_df = pd.DataFrame(extracted_records)

print("=== SMART DATA CLEANER OUTPUT ===")
print(f"Rows: {len(invoices_df)} | Columns: {len(invoices_df.columns)}")
print()
print(invoices_df.to_string(index=False))
# Out:
# === SMART DATA CLEANER OUTPUT ===
# Rows: 5 | Columns: 5
#
#    invoice_id            vendor_name  amount invoice_date    category
# INV-2024-0891    Techworld Solutions   45000   2024-01-15 Electronics
#          None      Priya Enterprises   12500   2024-02-07    Services
#  INV-2024-103 Arjun Nair Consultancy    8000   2024-03-15    Services
#          None    Suresh Rao Hardware   25000   2024-01-20 Accessories
#       INV-897  Ananya Tech Solutions   95000   2024-02-28 Electronics
